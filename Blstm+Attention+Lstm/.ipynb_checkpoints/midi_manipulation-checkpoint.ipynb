# %%
import midi
import numpy as np
from constants import *
import os
import tensorflow as tf
import math
import sys

# %%
def midiToNoteStateMatrix(midifile):

    pattern = midi.read_midifile(midifile)

    timeleft = [track[0].tick for track in pattern]

    posns = [0 for track in pattern]
    #for i, track in enumerate(pattern):
        #print(pattern[i][1].text)

    statematrix = []
    time = 0

    state = [[0,0,0] for x in range(NUM_NOTES)]
    statematrix.append(state)
    while True:
        if time % (pattern.resolution / 4) == (pattern.resolution / 8):
            # Crossed a note boundary. Create a new state, defaulting to holding notes
            oldstate = state
            state = [[oldstate[x][0],0,oldstate[x][2]] for x in range(NUM_NOTES)]
            statematrix.append(state)

        for i in range(len(timeleft)):
            while timeleft[i] == 0:
                track = pattern[i]
                pos = posns[i]

                evt = track[pos]
                if isinstance(evt, midi.NoteEvent):
                    if (evt.pitch < MIN_NOTE) or (evt.pitch >= MAX_NOTE):
                        print("Note {} at time {} out of bounds (ignoring)".format(evt.pitch, time))
                        pass
                    else:
                        if isinstance(evt, midi.NoteOffEvent) or evt.velocity == 0:
                            state[evt.pitch-MIN_NOTE] = [0, 0, 0]
                        else:
                            state[evt.pitch-MIN_NOTE] = [1, 1, evt.velocity/MAX_VELOCITY]
                elif isinstance(evt, midi.TimeSignatureEvent):
                    #print(evt)
                    if evt.numerator not in (2, 4):
                        # We don't want to worry about non-4 time signatures. Bail early!
                        print("Found time signature event {}. Bailing!".format(evt))
                        np.asarray(statematrix)

                try:
                    timeleft[i] = track[pos + 1].tick
                    posns[i] += 1
                except IndexError:
                    timeleft[i] = None

            if timeleft[i] is not None:
                timeleft[i] -= 1

        if all(t is None for t in timeleft):
            break

        time += 1
    #print(time)
    return np.asarray(statematrix)

# %%
def noteStateMatrixToMidi(vel_statematrix, name="example"):
    
    statematrix = []
    
    for i, timestep in enumerate(vel_statematrix):
        timestep_vel = []
        for note in timestep:
            timestep_vel.append([note[0], note[1], int(np.floor(note[2]*MAX_VELOCITY))])
        statematrix.append(timestep_vel)
    
    statematrix = np.asarray(statematrix, dtype='int')
    pattern = midi.Pattern()
    track = midi.Track()
    pattern.append(track)

    tickscale = 55
    
    lastcmdtime = 0
    prevstate = [[0,0,0] for x in range(NUM_NOTES)]
    for time, state in enumerate(statematrix + [prevstate[:]]):  
        offNotes = []
        onNotes = []
        for i in range(NUM_NOTES):
            n = state[i]
            p = prevstate[i]
            v = n[2]
            if p[0] == 1:
                if n[0] == 0:
                    offNotes.append(i)
                elif n[1] == 1:
                    offNotes.append(i)
                    onNotes.append([i, v])
            elif n[0] == 1:
                onNotes.append([i, v])
        for note in offNotes:
            track.append(midi.NoteOffEvent(tick=(time-lastcmdtime)*tickscale, pitch=note+MIN_NOTE))
            lastcmdtime = time
        for note in onNotes:
            track.append(midi.NoteOnEvent(tick=(time-lastcmdtime)*tickscale, velocity=note[1], pitch=note[0]+MIN_NOTE))
            lastcmdtime = time
            
        prevstate = state
    
    eot = midi.EndOfTrackEvent(tick=1)
    track.append(eot)
    
    midi.write_midifile("{}.mid".format(name), pattern)

# %%
nsm = midiToNoteStateMatrix('C:\\Users\\Lukya\\MachineLearning\\DataSets\\MusicGeneration\\Classical\\bach\\bach_847.mid')
# Out:
# Note 84 at time 99840 out of bounds (ignoring)
# Note 84 at time 99960 out of bounds (ignoring)

# %%
noteStateMatrixToMidi(nsm, 'C:\\Users\\Lukya\\MachineLearning\\DataSets\\MusicGeneration\\Classical\\bach\\bachtest2')

# %%
def startSentinel():
    def noteSentinel(note):
        position = note
        part_position = [position]
        
        pitchclass = (note + lowerBound) % 12
        part_pitchclass = [int(i == pitchclass) for i in range(12)]
        
        return part_position + part_pitchclass + [0]*66 + [1] 
    return [noteSentinel(note) for note in range(upperBound-lowerBound)]

# %%
def getOrDefault(l, i, d):
    try:
        return l[i]
    except IndexError:
        return d

# %%
def buildContext(state):
    context = [0]*12
    for note, notestate in enumerate(state):
        if notestate[0] == 1:
            pitchclass = (note + lowerBound) % 12
            context[pitchclass] += 1
    return context

# %%
md = midiToNoteStateMatrix(file)
# Out:
# 119040

# %%
def buildBeat(time):
    return [2*x-1 for x in [time%2, (time//2)%2, (time//4)%2, (time//8)%2]]

# %%
buildBeat(481)
# Out:
# [1, -1, -1, -1]

# %%
def one_hot(i, nb_classes):                       #Ставит еденицу на на место i из nb_classes, где все нули
    arr = np.zeros((nb_classes,))
    arr[i] = 1
    return arr

# %%
def get_all_files(rootdir):

    potential_files=[]

    for subdir, dirs, files in os.walk(rootdir):
        if (subdir.split('/')[-1] != "Classical"):
            dirname = subdir.split('/')[-1]
            sys.stdout.write("Parsing dir: %s" % dirname)
            print()
            sys.stdout.write("Parsing file number: \n")

        for i, filename in enumerate(files):
            sys.stdout.write("%s: " % (i+1))
            file = subdir + '/' + filename
            print(filename)
            potential_files.append(file)

        print()
    return potential_files

# %%
files = get_all_files('../DataSets/MusicGeneration/Classical')
# Out:
# Parsing dir: Classical\albeniz
# Parsing file number:
# 1: alb_esp1.mid
# 2: alb_esp2.mid
# 3: alb_esp3.mid
# 4: alb_esp4.mid
# 5: alb_esp5.mid
# 6: alb_esp6.mid
# 7: alb_se1.mid
# 8: alb_se2.mid
# 9: alb_se3.mid
# 10: alb_se4.mid
# 11: alb_se5.mid
# 12: alb_se6.mid
# 13: alb_se7.mid
# 14: alb_se8.mid
#
# Parsing dir: Classical\bach
# Parsing file number:
# 1: bach_846.mid
# 2: bach_847.mid
# 3: bach_850.mid
#
# Parsing dir: Classical\balakir
# Parsing file number:
# 1: islamei.mid
#
# Parsing dir: Classical\beeth
# Parsing file number:
# 1: appass_1.mid
# 2: appass_2.mid
# 3: appass_3.mid
# 4: beethoven_hammerklavier_1.mid
# 5: beethoven_hammerklavier_2.mid
# 6: beethoven_hammerklavier_3.mid
# 7: beethoven_hammerklavier_4.mid
# 8: beethoven_les_adieux_1.mid
# 9: beethoven_les_adieux_2.mid
# 10: beethoven_les_adieux_3.mid
# 11: beethoven_opus10_1.mid
# 12: beethoven_opus10_2.mid
# 13: beethoven_opus10_3.mid
# 14: beethoven_opus22_1.mid
# 15: beethoven_opus22_2.mid
# 16: beethoven_opus22_3.mid
# 17: beethoven_opus22_4.mid
# 18: beethoven_opus90_1.mid
# 19: beethoven_opus90_2.mid
# 20: elise.mid
# 21: mond_1.mid
# 22: mond_2.mid
# 23: mond_3.mid
# 24: pathetique_1.mid
# 25: pathetique_2.mid
# 26: pathetique_3.mid
# 27: waldstein_1.mid
# 28: waldstein_2.mid
# 29: waldstein_3.mid
#
# Parsing dir: Classical\borodin
# Parsing file number:
# 1: bor_ps1.mid
# 2: bor_ps2.mid
# 3: bor_ps3.mid
# 4: bor_ps4.mid
# 5: bor_ps5.mid
# 6: bor_ps6.mid
# 7: bor_ps7.mid
#
# Parsing dir: Classical\brahms
# Parsing file number:
# 1: brahms_opus117_1.mid
# 2: brahms_opus117_2.mid
# 3: brahms_opus1_1.mid
# 4: brahms_opus1_2.mid
# 5: brahms_opus1_3.mid
# 6: brahms_opus1_4.mid
# 7: br_im2.mid
# 8: br_im5.mid
# 9: BR_IM6.MID
# 10: br_rhap.mid
#
# Parsing dir: Classical\burgm
# Parsing file number:
# 1: burg_agitato.mid
# 2: burg_erwachen.mid
# 3: burg_geschwindigkeit.mid
# 4: burg_gewitter.mid
# 5: burg_perlen.mid
# 6: burg_quelle.mid
# 7: burg_spinnerlied.mid
# 8: burg_sylphen.mid
# 9: burg_trennung.mid
#
# Parsing dir: Classical\chopin
# Parsing file number:
# 1: chpn-p1.mid
# 2: chpn-p10.mid
# 3: chpn-p11.mid
# 4: chpn-p12.mid
# 5: chpn-p13.mid
# 6: chpn-p14.mid
# 7: chpn-p15.mid
# 8: chpn-p16.mid
# 9: chpn-p17.mid
# 10: chpn-p18.mid
# 11: chpn-p19.mid
# 12: chpn-p2.mid
# 13: chpn-p20.mid
# 14: chpn-p21.mid
# 15: chpn-p22.mid
# 16: chpn-p23.mid
# 17: chpn-p24.mid
# 18: chpn-p3.mid
# 19: chpn-p4.mid
# 20: chpn-p5.mid
# 21: chpn-p6.mid
# 22: chpn-p7.mid
# 23: chpn-p8.mid
# 24: chpn-p9.mid
# 25: chpn_op10_e01.mid
# 26: chpn_op10_e05.mid
# 27: chpn_op10_e12.mid
# 28: chpn_op23.mid
# 29: chpn_op25_e1.mid
# 30: chpn_op25_e11.mid
# 31: chpn_op25_e12.mid
# 32: chpn_op25_e2.mid
# 33: chpn_op25_e3.mid
# 34: chpn_op25_e4.mid
# 35: chpn_op27_1.mid
# 36: chpn_op27_2.mid
# 37: chpn_op33_2.mid
# 38: chpn_op33_4.mid
# 39: chpn_op35_1.mid
# 40: chpn_op35_2.mid
# 41: chpn_op35_3.mid
# 42: chpn_op35_4.mid
# 43: chpn_op53.mid
# 44: chpn_op66.mid
# 45: chpn_op7_1.mid
# 46: chpn_op7_2.mid
# 47: chp_op18.mid
# 48: chp_op31.mid
#
# Parsing dir: Classical\debussy
# Parsing file number:
# 1: debussy_cc_1.mid
# 2: debussy_cc_2.mid
# 3: debussy_cc_3.mid
# 4: debussy_cc_4.mid
# 5: debussy_cc_6.mid
# 6: DEB_CLAI.MID
# 7: deb_menu.mid
# 8: DEB_PASS.MID
# 9: deb_prel.mid
#
# Parsing dir: Classical\granados
# Parsing file number:
# 1: gra_esp_2.mid
# 2: gra_esp_3.mid
# 3: gra_esp_4.mid
#
# Parsing dir: Classical\grieg
# Parsing file number:
# 1: grieg_album.mid
# 2: grieg_berceuse.mid
# 3: grieg_brooklet.mid
# 4: grieg_butterfly.mid
# 5: grieg_elfentanz.mid
# 6: grieg_halling.mid
# 7: grieg_kobold.mid
# 8: grieg_march.mid
# 9: grieg_once_upon_a_time.mid
# 10: grieg_spring.mid
# 11: grieg_voeglein.mid
# 12: grieg_waechter.mid
# 13: grieg_walzer.mid
# 14: grieg_wanderer.mid
# 15: grieg_wedding.mid
# 16: grieg_zwerge.mid
#
# Parsing dir: Classical\haydn
# Parsing file number:
# 1: haydn_33_1.mid
# 2: haydn_33_2.mid
# 3: haydn_33_3.mid
# 4: haydn_35_1.mid
# 5: haydn_35_2.mid
# 6: haydn_35_3.mid
# 7: haydn_43_1.mid
# 8: haydn_43_2.mid
# 9: haydn_43_3.mid
# 10: haydn_7_1.mid
# 11: haydn_7_2.mid
# 12: haydn_7_3.mid
# 13: haydn_8_1.mid
# 14: haydn_8_2.mid
# 15: haydn_8_3.mid
# 16: haydn_8_4.mid
# 17: haydn_9_1.mid
# 18: haydn_9_2.mid
# 19: haydn_9_3.mid
# 20: hay_40_1.mid
# 21: hay_40_2.mid
#
# Parsing dir: Classical\liszt
# Parsing file number:
# 1: liz_donjuan.mid
# 2: liz_et1.mid
# 3: liz_et2.mid
# 4: liz_et3.mid
# 5: liz_et4.mid
# 6: liz_et5.mid
# 7: liz_et6.mid
# 8: liz_et_trans4.mid
# 9: liz_et_trans5.mid
# 10: liz_et_trans8.mid
# 11: liz_liebestraum.mid
# 12: liz_rhap02.mid
# 13: liz_rhap09.mid
# 14: liz_rhap10.mid
# 15: liz_rhap12.mid
# 16: liz_rhap15.mid
#
# Parsing dir: Classical\mendelssohn
# Parsing file number:
# 1: mendel_op19_1.mid
# 2: mendel_op19_2.mid
# 3: mendel_op19_3.mid
# 4: mendel_op19_4.mid
# 5: mendel_op19_5.mid
# 6: mendel_op19_6.mid
# 7: mendel_op30_1.mid
# 8: mendel_op30_2.mid
# 9: mendel_op30_3.mid
# 10: mendel_op30_4.mid
# 11: mendel_op30_5.mid
# 12: mendel_op53_5.mid
# 13: mendel_op62_3.mid
# 14: mendel_op62_4.mid
# 15: mendel_op62_5.mid
#
# Parsing dir: Classical\mozart
# Parsing file number:
# 1: mz_311_1.mid
# 2: mz_311_2.mid
# 3: mz_311_3.mid
# 4: mz_330_1.mid
# 5: mz_330_2.mid
# 6: mz_330_3.mid
# 7: mz_331_1.mid
# 8: mz_331_2.mid
# 9: mz_331_3.mid
# 10: mz_332_1.mid
# 11: mz_332_2.mid
# 12: mz_332_3.mid
# 13: mz_333_1.mid
# 14: mz_333_2.mid
# 15: mz_333_3.mid
# 16: mz_545_1.mid
# 17: mz_545_2.mid
# 18: mz_545_3.mid
# 19: mz_570_1.mid
# 20: mz_570_2.mid
# 21: mz_570_3.mid
#
# Parsing dir: Classical\muss
# Parsing file number:
# 1: muss_1.mid
# 2: muss_2.mid
# 3: muss_3.mid
# 4: muss_4.mid
# 5: muss_5.mid
# 6: muss_6.mid
# 7: muss_7.mid
# 8: muss_8.mid
#
# Parsing dir: Classical\schubert
# Parsing file number:
# 1: schubert_D850_1.mid
# 2: schubert_D850_2.mid
# 3: schubert_D850_3.mid
# 4: schubert_D850_4.mid
# 5: schubert_D935_1.mid
# 6: schubert_D935_2.mid
# 7: schubert_D935_3.mid
# 8: schubert_D935_4.mid
# 9: schub_d760_1.mid
# 10: schub_d760_2.mid
# 11: schub_d760_3.mid
# 12: schub_d760_4.mid
# 13: schub_d960_1.mid
# 14: schub_d960_2.mid
# 15: schub_d960_3.mid
# 16: schub_d960_4.mid
# 17: schuim-1.mid
# 18: schuim-2.mid
# 19: schuim-3.mid
# 20: schuim-4.mid
# 21: schumm-1.mid
# 22: schumm-2.mid
# 23: schumm-3.mid
# 24: schumm-4.mid
# 25: schumm-5.mid
# 26: schumm-6.mid
# 27: schu_143_1.mid
# 28: schu_143_2.mid
# 29: schu_143_3.mid
#
# Parsing dir: Classical\schumann
# Parsing file number:
# 1: schum_abegg.mid
# 2: scn15_1.mid
# 3: scn15_10.mid
# 4: scn15_11.mid
# 5: scn15_12.mid
# 6: scn15_13.mid
# 7: scn15_2.mid
# 8: scn15_3.mid
# 9: scn15_4.mid
# 10: scn15_5.mid
# 11: scn15_6.mid
# 12: scn15_7.mid
# 13: scn15_8.mid
# 14: scn15_9.mid
# 15: scn16_1.mid
# 16: scn16_2.mid
# 17: scn16_3.mid
# 18: scn16_4.mid
# 19: scn16_5.mid
# 20: scn16_6.mid
# 21: scn16_7.mid
# 22: scn16_8.mid
# 23: scn68_10.mid
# 24: scn68_12.mid
#
# Parsing dir: Classical\tschai
# Parsing file number:
# 1: ty_april.mid
# 2: ty_august.mid
# 3: ty_dezember.mid
# 4: ty_februar.mid
# 5: ty_januar.mid
# 6: ty_juli.mid
# 7: ty_juni.mid
# 8: ty_maerz.mid
# 9: ty_mai.mid
# 10: ty_november.mid
# 11: ty_oktober.mid
# 12: ty_september.mid

# %%
len(files)
# Out:
# 295
